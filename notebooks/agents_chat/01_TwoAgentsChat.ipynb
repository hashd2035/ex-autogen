# %%
from configs import LlmConfigs
import autogen


assistant = autogen.AssistantAgent(
    name="Assistant",
    llm_config=LlmConfigs.OpenAi.gpt4
)

user_proxy = autogen.UserProxyAgent(
    name="user",
    human_input_mode="ALWAYS",
    code_execution_config={
        "work_dir": "coding",
        "use_docker": False
    }
)

user_proxy.initiate_chat(assistant, message="Plot a chart of META and TESLA stock price change.")
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from configs import LlmConfigs
#       2 import autogen
#       5 assistant = autogen.AssistantAgent(
#       6     name="Assistant",
#       7     llm_config=LlmConfigs.OpenAi.gpt4
#       8 )
#
# File ~/Src/agent_exercises/ex-autogen/autogenex/configs/__init__.py:1
# ----> 1 from .code_execution_config import CodeExecutionConfig
#       2 from .llmconfigs import LlmConfigs
#       4 from dotenv import load_dotenv
#
# File ~/Src/agent_exercises/ex-autogen/autogenex/configs/code_execution_config.py:2
#       1 import os
# ----> 2 from autogen.coding import DockerCommandLineCodeExecutor, LocalCommandLineCodeExecutor
#       3 from dotenv import load_dotenv
#       4 load_dotenv()
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/autogen/__init__.py:3
#       1 import logging
# ----> 3 from .agentchat import *
#       4 from .code_utils import DEFAULT_MODEL, FAST_MODEL
#       5 from .exception_utils import *
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/autogen/agentchat/__init__.py:2
#       1 from .agent import Agent
# ----> 2 from .assistant_agent import AssistantAgent
#       3 from .chat import ChatResult, initiate_chats
#       4 from .conversable_agent import ConversableAgent, register_function
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/autogen/agentchat/assistant_agent.py:5
#       1 from typing import Callable, Dict, Literal, Optional, Union
#       3 from autogen.runtime_logging import log_new_agent, logging_enabled
# ----> 5 from .conversable_agent import ConversableAgent
#       8 class AssistantAgent(ConversableAgent):
#       9     """(In preview) Assistant agent, designed to solve a task with LLM.
#      10
#      11     AssistantAgent is a subclass of ConversableAgent configured with a default system message.
#    (...)
#      16     This agent doesn't execute code by default, and expects the user to execute the code.
#      17     """
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:19
#      17 from .._pydantic import model_dump
#      18 from ..cache.cache import AbstractCache
# ---> 19 from ..code_utils import (
#      20     PYTHON_VARIANTS,
#      21     UNKNOWN,
#      22     check_can_use_docker_or_throw,
#      23     content_str,
#      24     decide_use_docker,
#      25     execute_code,
#      26     extract_code,
#      27     infer_lang,
#      28 )
#      29 from ..coding.base import CodeExecutor
#      30 from ..coding.factory import CodeExecutorFactory
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/autogen/code_utils.py:17
#      13 from typing import Any, Callable, Dict, List, Optional, Tuple, Union
#      15 import docker
# ---> 17 from autogen import oai
#      19 from .types import UserMessageImageContentPart, UserMessageTextContentPart
#      21 SENTINEL = object()
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/autogen/oai/__init__.py:3
#       1 from autogen.cache.cache import Cache
#       2 from autogen.oai.client import ModelClient, OpenAIWrapper
# ----> 3 from autogen.oai.completion import ChatCompletion, Completion
#       4 from autogen.oai.openai_utils import (
#       5     config_list_from_dotenv,
#       6     config_list_from_json,
#    (...)
#      11     get_config_list,
#      12 )
#      14 __all__ = [
#      15     "OpenAIWrapper",
#      16     "ModelClient",
#    (...)
#      26     "Cache",
#      27 ]
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/autogen/oai/completion.py:10
#       7 from typing import Callable, Dict, List, Optional, Union
#       9 import numpy as np
# ---> 10 from flaml import BlendSearch, tune
#      11 from flaml.tune.space import is_constant
#      13 from .client_utils import logger_formatter
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/flaml/__init__.py:4
#       1 import logging
#       3 try:
# ----> 4     from flaml.automl import AutoML, logger_formatter
#       6     has_automl = True
#       7 except ImportError:
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/flaml/automl/__init__.py:4
#       1 from flaml.automl.logger import logger_formatter
#       3 try:
# ----> 4     from flaml.automl.automl import AutoML, size
#       5     from flaml.automl.state import AutoMLState, SearchState
#       7     __all__ = ["AutoML", "AutoMLState", "SearchState", "logger_formatter", "size"]
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/flaml/automl/automl.py:20
#      18 from flaml import tune
#      19 from flaml.automl.logger import logger, logger_formatter
# ---> 20 from flaml.automl.ml import huggingface_metric_to_mode, sklearn_metric_name_set, spark_metric_name_dict, train_estimator
#      21 from flaml.automl.spark import DataFrame, Series, psDataFrame, psSeries
#      22 from flaml.automl.state import AutoMLState, SearchState
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/flaml/automl/ml.py:12
#       9 import numpy as np
#      11 from flaml.automl.data import group_counts
# ---> 12 from flaml.automl.model import BaseEstimator, TransformersEstimator
#      13 from flaml.automl.spark import ERROR as SPARK_ERROR
#      14 from flaml.automl.spark import DataFrame, Series, psDataFrame, psSeries
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/flaml/automl/model.py:26
#      24 from sklearn.preprocessing import Normalizer
#      25 from sklearn.svm import LinearSVC
# ---> 26 from xgboost import __version__ as xgboost_version
#      28 from flaml import tune
#      29 from flaml.automl.data import group_counts
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective, dask
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)
#      15     build_info,
#      16 )
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/xgboost/tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/xgboost/core.py:269
#     265     return lib
#     268 # load the XGBoost library globally
# --> 269 _LIB = _load_lib()
#     272 def _check_call(ret: int) -> None:
#     273     """Check the return value of C API call
#     274
#     275     This function will raise exception when error occurs.
#    (...)
#     281         return value from API calls
#     282     """
#
# File ~/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/xgboost/core.py:222, in _load_lib()
#     220     if not lib_success:
#     221         libname = os.path.basename(lib_paths[0])
# --> 222         raise XGBoostError(
#     223             f"""
#     224 XGBoost Library ({libname}) could not be loaded.
#     225 Likely causes:
#     226   * OpenMP runtime is not installed
#     227     - vcomp140.dll or libgomp-1.dll for Windows
#     228     - libomp.dylib for Mac OSX
#     229     - libgomp.so for Linux and other UNIX-like OSes
#     230     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#     231
#     232   * You are running 32-bit Python on a 64-bit OS
#     233
#     234 Error message(s): {os_error_list}
#     235 """
#     236         )
#     237     _register_log_callback(lib)
#     239     def parse(ver: str) -> Tuple[int, int, int]:
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ['dlopen(/Users/jameskim/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: @rpath/libomp.dylib\n  Referenced from: /Users/jameskim/Src/agent_exercises/ex-autogen/.venv/lib/python3.12/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']
